# %%
from os.path import abspath
from pyspark.sql import SparkSession

#enableHiveSupport() -> enables sparkSession to connect with Hive
warehouse_location = abspath('spark-warehouse')
spark = SparkSession \
    .builder \
    .appName("SparkByExamples.com") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .enableHiveSupport() \
    .getOrCreate()
spark
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/08/12 20:42:50 WARN Utils: Your hostname, MacBook-Pro-de-Eduardo.local, resolves to a loopback address: 127.0.0.1; using 192.168.3.96 instead (on interface en0)
# 25/08/12 20:42:50 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/08/12 20:42:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.3.96:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>SparkByExamples.com</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.sql("create database if not exists proddb150")
spark.sql("show databases;")
spark.sql("show SCHEMAS;").show()
# Out:
# 25/08/12 20:43:19 WARN ObjectStore: Version information not found in metastore. hive.metastore.schema.verification is not enabled so recording the schema version 2.3.0
# 25/08/12 20:43:19 WARN ObjectStore: setMetaStoreSchemaVersion called but recording version is disabled: version = 2.3.0, comment = Set by MetaStore eduardoalberto@127.0.0.1
# 25/08/12 20:43:19 WARN ObjectStore: Failed to get database default, returning NoSuchObjectException
# 25/08/12 20:43:19 WARN ObjectStore: Failed to get database proddb150, returning NoSuchObjectException
# 25/08/12 20:43:19 WARN ObjectStore: Failed to get database proddb150, returning NoSuchObjectException
# 25/08/12 20:43:19 WARN ObjectStore: Failed to get database proddb150, returning NoSuchObjectException
# +---------+
# |namespace|
# +---------+
# |  default|
# |proddb150|
# +---------+
