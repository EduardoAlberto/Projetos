# %%
from pyspark.sql import SparkSession
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://eduardoadsantos:Admin123@cluster0.3b4yvax.mongodb.net/"

spark = (
    SparkSession.builder
    .appName("MongoAtlasPySpark")
    .config("spark.mongodb.read.connection.uri", uri)
    .config("spark.mongodb.write.connection.uri", uri)
    .getOrCreate()
)

df = (
    spark.read.format("mongodb")
    .option("database", "sample_mflix")
    .option("collection", "movies")
    .load()
)

df.show()
# df.printSchema()
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+--------------------+---------+--------------------+--------------------+--------------------+------------------+---------+--------------------+----------+------------------+--------------------+--------------------+--------+-------------------+-------+--------------------+--------------------+-----+--------------------+----+
# |                 _id|              awards|                cast|countries|           directors|            fullplot|              genres|              imdb|languages|         lastupdated|metacritic|num_mflix_comments|                plot|              poster|   rated|           released|runtime|               title|            tomatoes| type|             writers|year|
# +--------------------+--------------------+--------------------+---------+--------------------+--------------------+--------------------+------------------+---------+--------------------+----------+------------------+--------------------+--------------------+--------+-------------------+-------+--------------------+--------------------+-----+--------------------+----+
# |573a1390f29313caa...|      {1, 0, 1 win.}|[A.C. Abadie, Gil...|    [USA]|   [Edwin S. Porter]|Among the earlies...|    [Short, Western]|  {439, 7.4, 9847}|[English]|2015-08-13 00:27:...|      NULL|                 0|A group of bandit...|https://m.media-a...|    TV-G|1903-11-30 20:53:32|     11|The Great Train R...|{NULL, NULL, {100...|movie|                NULL|1903|
# |573a1390f29313caa...|      {1, 0, 1 win.}|[Frank Powell, Gr...|    [USA]|     [D.W. Griffith]|A greedy tycoon d...|      [Short, Drama]|  {832, 6.6, 1375}|[English]|2015-08-13 00:46:...|      NULL|                 1|A greedy tycoon d...|                NULL|       G|1909-12-12 20:53:32|     14|   A Corner in Wheat|{NULL, NULL, NULL...|movie|                NULL|1909|
# |573a1390f29313caa...|      {1, 0, 1 win.}|      [Winsor McCay]|    [USA]|[Winsor McCay, J....|Cartoonist Winsor...|[Animation, Short...| {1737, 7.3, 1034}|[English]|2015-08-29 01:09:...|      NULL|                 0|Cartoon figures a...|https://m.media-a...|    NULL|1911-04-07 20:53:32|      7|Winsor McCay, the...|{NULL, NULL, NULL...|movie|[Winsor McCay (co...|1911|
# |573a1390f29313caa...|      {1, 0, 1 win.}|[Jane Gail, Ethel...|    [USA]|[George Loane Tuc...|                NULL|      [Crime, Drama]|  {3471, 6.0, 371}|[English]|2015-09-15 02:07:...|      NULL|                 1|A woman, with the...|https://m.media-a...|   TV-PG|1913-11-23 20:53:32|     88|    Traffic in Souls|{NULL, NULL, NULL...|movie|                NULL|1913|
# |573a1390f29313caa...|      {1, 0, 1 win.}|[Winsor McCay, Ge...|    [USA]|      [Winsor McCay]|Winsor Z. McCay b...|[Animation, Short...| {4008, 7.3, 1837}|[English]|2015-08-18 01:03:...|      NULL|                 0|The cartoonist, W...|https://m.media-a...|    NULL|1914-09-14 21:00:00|     12| Gertie the Dinosaur|{NULL, NULL, NULL...|movie|      [Winsor McCay]|1914|
# |573a1390f29313caa...|      {1, 0, 1 win.}|[Tula Belle, Robi...|    [USA]|  [Maurice Tourneur]|Two peasant child...|           [Fantasy]|  {8891, 6.6, 446}|[English]|2015-07-20 00:32:...|      NULL|                 0|Two peasant child...|https://m.media-a...|    NULL|1918-03-30 21:00:00|     75|       The Blue Bird|{NULL, NULL, NULL...|movie|[Maurice Maeterli...|1918|
# |573a1391f29313caa...|{0, 1, 1 nominati...|[Harold Lloyd, Mi...|    [USA]|[Alfred J. Gouldi...|As a penniless ma...|[Comedy, Short, A...| {10146, 7.0, 639}|[English]|2015-04-17 00:16:...|      NULL|                 0|A penniless young...|https://m.media-a...|    TV-G|1919-12-27 21:00:00|     22|  From Hand to Mouth|{NULL, NULL, NULL...|movie|[H.M. Walker (tit...|1919|
# |573a1391f29313caa...|{0, 1, 1 nominati...|[Harold Lloyd, Ro...|    [USA]|         [Hal Roach]|After a long wait...|     [Comedy, Short]| {11293, 7.0, 646}|[English]|2015-08-11 00:35:...|      NULL|                 1|A tipsy doctor en...|https://m.media-a...|  PASSED|1920-07-10 21:00:00|     26|      High and Dizzy|{NULL, NULL, NULL...|movie|[Frank Terry (sto...|1920|
# |573a1391f29313caa...|      {1, 0, 1 win.}|[Buster Keaton, S...|    [USA]|[Edward F. Cline,...|Buster and Sybil ...|     [Short, Comedy]|{11541, 8.3, 3942}|[English]|2015-05-07 01:07:...|      NULL|                 0|A newly wedded co...|                NULL|    TV-G|1920-08-31 21:00:00|     25|            One Week|{NULL, NULL, NULL...|movie|                NULL|1920|
# |573a1391f29313caa...|{0, 1, 1 nominati...|[Edward Jobson, B...|    [USA]|[Herbert Blachè, ...|Nick Van Alstyne ...|            [Comedy]|{11652, 6.2, 1020}|     NULL|2015-06-20 00:38:...|      NULL|                 0|The simple-minded...|https://m.media-a...|    NULL|1920-08-31 21:00:00|     77|         The Saphead|{NULL, NULL, NULL...|movie|[Bronson Howard (...|1920|
# |573a1391f29313caa...|{0, 2, 2 nominati...|[Lon Chaney, Leat...|    [USA]|   [Wallace Worsley]|A secret society ...|[Crime, Drama, My...| {11904, 7.0, 798}|     NULL|2015-07-20 00:01:...|      NULL|                 1|A romantic rivalr...|https://m.media-a...|  PASSED|1924-04-03 21:00:00|     75|   The Ace of Hearts|{NULL, NULL, NULL...|movie|[Gouverneur Morri...|1921|
# |573a1391f29313caa...|      {1, 0, 1 win.}|[Pomeroy Cannon, ...|    [USA]|        [Rex Ingram]|Julio Madariaga i...|[Drama, Romance, ...|{12190, 7.9, 2475}|     NULL|2015-08-24 00:59:...|      NULL|                 1|An extended famil...|https://m.media-a...|  PASSED|1923-03-30 21:00:00|    150|The Four Horsemen...|{NULL, NULL, NULL...|movie|[Vicente Blasco I...|1921|
# +--------------------+--------------------+--------------------+---------+--------------------+--------------------+--------------------+------------------+---------+--------------------+----------+------------------+--------------------+--------------------+--------+-------------------+-------+--------------------+--------------------+-----+--------------------+----+
# only showing top 20 rows
#
# root
#  |-- _id: string (nullable = true)
#  |-- awards: struct (nullable = true)
#  |    |-- wins: integer (nullable = true)
#  |    |-- nominations: integer (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- cast: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- countries: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- directors: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- fullplot: string (nullable = true)
#  |-- genres: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- imdb: struct (nullable = true)
#  |    |-- id: integer (nullable = true)
#  |    |-- rating: string (nullable = true)
#  |    |-- votes: string (nullable = true)
#  |-- languages: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- lastupdated: string (nullable = true)
#  |-- metacritic: integer (nullable = true)
#  |-- num_mflix_comments: integer (nullable = true)
#  |-- plot: string (nullable = true)
#  |-- poster: string (nullable = true)
#  |-- rated: string (nullable = true)
#  |-- released: timestamp (nullable = true)
#  |-- runtime: integer (nullable = true)
#  |-- title: string (nullable = true)
#  |-- tomatoes: struct (nullable = true)
#  |    |-- boxOffice: string (nullable = true)
#  |    |-- consensus: string (nullable = true)
#  |    |-- critic: struct (nullable = true)
#  |    |    |-- meter: integer (nullable = true)
#  |    |    |-- numReviews: integer (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- dvd: timestamp (nullable = true)
#  |    |-- fresh: integer (nullable = true)
#  |    |-- lastUpdated: timestamp (nullable = true)
#  |    |-- production: string (nullable = true)
#  |    |-- rotten: integer (nullable = true)
#  |    |-- viewer: struct (nullable = true)
#  |    |    |-- meter: integer (nullable = true)
#  |    |    |-- numReviews: integer (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- website: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- writers: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- year: string (nullable = true)

# %%
df.count()
# Out:
# 21349

# %%
# !pip3 install FastAPI
# Out:
# Collecting FastAPI
#   Downloading fastapi-0.128.0-py3-none-any.whl.metadata (30 kB)
# Collecting starlette<0.51.0,>=0.40.0 (from FastAPI)
#   Downloading starlette-0.49.3-py3-none-any.whl.metadata (6.4 kB)
# Collecting pydantic>=2.7.0 (from FastAPI)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/eduardoalberto/Library/Python/3.9/lib/python/site-packages (from FastAPI) (4.14.1)
# Collecting annotated-doc>=0.0.2 (from FastAPI)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from starlette<0.51.0,>=0.40.0->FastAPI) (4.10.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/eduardoalberto/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->FastAPI) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->FastAPI) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->FastAPI) (1.3.1)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.7.0->FastAPI)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.7.0->FastAPI)
#   Downloading pydantic_core-2.41.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.7.0->FastAPI)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading fastapi-0.128.0-py3-none-any.whl (103 kB)
# Downloading starlette-0.49.3-py3-none-any.whl (74 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp39-cp39-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 89.7 MB/s  0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, pydantic-core, annotated-types, annotated-doc, pydantic, starlette, FastAPI
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [FastAPI]m5/7 [starlette]
# Successfully installed FastAPI-0.128.0 annotated-doc-0.0.4 annotated-types-0.7.0 pydantic-2.12.5 pydantic-core-2.41.5 starlette-0.49.3 typing-inspection-0.4.2
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
